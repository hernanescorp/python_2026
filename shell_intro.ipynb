# %% [markdown]
# <a href="https://colab.research.google.com/github/hernanescorp/python_2026/blob/main/shell_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INTRODUCTION TO TERMINAL AND PYTHON**

# %% [markdown]
# ## **COMMANDS AND UBUNTU**

# %% [markdown]
# Shows in wich directory are you

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# List directories

# %%
ls
# Out:
# sample_data/

# %% [markdown]
# Go to directory

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
pwd
# Out:
# '/content/sample_data'

# %%
ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %% [markdown]
# Create directory

# %%
cd ..
# Out:
# /content

# %%
mkdir project

# %%
ls
# Out:
# project/  sample_data/

# %%
ll
# Out:
# total 8
# drwxr-xr-x 2 root 4096 Feb  8 16:48 project/
# drwxr-xr-x 1 root 4096 Jan 16 14:24 sample_data/

# %%
cd project/
# Out:
# /content/project

# %% [markdown]
# Remove directory

# %%
cd ..
# Out:
# /content

# %%
rmdir project/

# %%
ls
# Out:
# sample_data/

# %% [markdown]
# Command Lines

# %%
# !echo 'This command print text in screen'
# !ls
# !pwd
# !cd
# Out:
# This command print text in screen
# sample_data
# /content

# %% [markdown]
# Install Libraries

# %%
# !pip install session-info
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 2.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Session Info**

# %%
# !pip install backports.functools_lru_cache
import session_info
session_info.show(excludes=['backports'])
# Out:
# ...
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# session_info        v1.0.1
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 11.3.0
# backcall            0.2.0
# certifi             2026.01.04
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0.post0
# debugpy             1.8.15
# decorator           4.4.2
# defusedxml          0.7.1
# entrypoints         0.4
# google              NA
# httplib2            0.31.2
# ipykernel           6.17.1
# ipython_genutils    0.2.0
# kiwisolver          1.4.9
# matplotlib          3.10.0
# matplotlib_inline   0.2.1
# mpl_toolkits        NA
# numpy               2.0.2
# packaging           26.0
# pexpect             4.9.0
# pickleshare         0.7.5
# platformdirs        4.5.1
# prompt_toolkit      3.0.52
# psutil              5.9.5
# ptyprocess          0.7.0
# pydev_ipython       NA
# ...

# %% [markdown]
# Commands for Data Science

# %%
from vega_datasets import data
import altair as alt

cars = data.cars()

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.shape
# Out:
# (406, 9)

# %%
cars.describe()
# Out:
#        Miles_per_Gallon   Cylinders  Displacement  Horsepower  Weight_in_lbs  \
# count        398.000000  406.000000    406.000000  400.000000     406.000000
# mean          23.514573    5.475369    194.779557  105.082500    2979.413793
# min            9.000000    3.000000     68.000000   46.000000    1613.000000
# 25%           17.500000    4.000000    105.000000   75.750000    2226.500000
# 50%           23.000000    4.000000    151.000000   95.000000    2822.500000
# 75%           29.000000    8.000000    302.000000  130.000000    3618.250000
# max           46.600000    8.000000    455.000000  230.000000    5140.000000
# std            7.815984    1.712160    104.922458   38.768779     847.004328
#
#        Acceleration                           Year
# count    406.000000                            406
# mean      15.519704  1975-12-30 13:49:57.044334976
# min        8.000000            1970-01-01 00:00:00
# 25%       13.700000            1973-01-01 00:00:00
# ...

# %%
(
    alt.Chart(cars)
    .mark_line()
    .encode(
        x = 'Year:T',
        y = 'count(Year):Q',
        color = 'Origin:N'
    )
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Tabular data in interactive sheets

# %%
# %load_ext google.colab.data_table
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %% [markdown]
# Unabled Interactive Data

# %%
# %unload_ext google.colab.data_table
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
# @title Origin
from matplotlib import pyplot as plt
import seaborn as sns

cars.groupby('Origin').size().plot(kind='barh')
plt.gca().spines[['top','right',]].set_visible(False)

# %% [markdown]
# ## **Init Git**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Activate python in linux:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# `upt update` : UPDATE
#
# `sudo apt update`: SUPERUSER

# %% [markdown]
# **Init cloning in github**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Commits**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *Always add readme and requirements in each project, in order to execute installing libraries*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Execute : ``` git clone ... ``` , and follow steps to colaborate. In the end of colab exec a pull request.
#
#
# 1.   ```pip3 install -r requirements. ```

# %% [markdown]
# **Generate requeriments.txt**:
#
#
# 1.   ``` pip3 freeze > requirements.txt ```
# 2.   ``` cat requirements.txt ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Know in which enviroment we are running :
#  0. ```python3 -m venv env``` Crear entorno
#  1. ```which python3 ```
#  2. ``` source env/bin/activate ``` Activate env
#  3. ```pip3 install matplotlib``` Install libraries
#  4. ```deactivate``` Deactivate env

# %% [markdown]
# ##**DOCKER**

# %% [markdown]
# In cloud could be exist problems with versions.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Create Container, run it, enable it**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Rebuilt, get down, upload and run container**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Vamos a sincronizar los archivos de forma que no haya que cerrar sesion cada vez que cambiamos el codigo**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
